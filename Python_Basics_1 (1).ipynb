# %%
import math

# %%
a=10
a
# Out:
# 10

# %%
b=10
b
# Out:
# 10

# %%
a+b
# Out:
# 20

# %%
1+1
# Out:
# 2

# %%
a=30
a
# Out:
# 30

# %%
## the single line comment 
## for single line use hash (may be single or double)
a=10
a
# Out:
# 10

# %%
"""
multiline comment 
"""
a=10
a
# Out:
# 10

# %% [markdown]
# 1. this is the raw line of the code

# %% [markdown]
# ## python numbers

# %%
1+3
# Out:
# 4

# %%
1+3
# Out:
# 4

# %%
print(1+3)
# Out:
# 4

# %%
1+3
# Out:
# 4

# %%
print("i work in tcs and \n learning Data Engineering")
# Out:
# i work in tcs and
#  learning Data Engineering

# %%
name='krish'
company="TCS"

# %%
name
# Out:
# 'krish'

# %%
print(name)
# Out:
# krish

# %%
name="kalyan"

# %%
name
# Out:
# 'kalyan'

# %%
company="gartner"

# %%
company
# Out:
# 'gartner'

# %%
type(" ")
# Out:
# str

# %%
decimaal=2.455
decimaal
# Out:
# 2.455

# %%
type(decimaal)
# Out:
# float

# %%
type(2+3j)
# Out:
# complex

# %%
type(2j)
# Out:
# complex

# %%
a=2
a
# Out:
# 2

# %%
number1=23

# %%
number1
# Out:
# 23

# %%
company="gartner"
Company="Pw SKills"

# %%
company
# Out:
# 'gartner'

# %%
Company
# Out:
# 'Pw SKills'

# %%
int=12

# %%
int
# Out:
# 12

# %%
type(int)
# Out:
# int

# %%
a=23
a
# Out:
# 23

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
type(not False)
# Out:
# bool

# %%
bool(1)
# Out:
# True

# %%
a=1

# %%
if(bool(a)==True):
    print('Krish')    #typecasting
# Out:
# Krish

# %%
a=10

# %%
str(a)
# Out:
# '10'

# %%
a='23'
a
# Out:
# '23'

# %%
type(int(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-95884019c7e5> in <module>
# ----> 1 type(int(a))
#
# TypeError: 'int' object is not callable

# %%
a='A'
a
# Out:
# 'A'

# %%
int(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-8b2ab3991dae> in <module>
# ----> 1 int(a)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### dynamic typing

# %%
a=12

# %%
type(a)
# Out:
# int

# %%
str1="krish"

# %%
str1
# Out:
# 'krish'

# %%
a='var'

# %%
a
# Out:
# 'var'

# %%
type(a)
# Out:
# str

# %%
a1="shreya"
int(a1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-96d5ad6b88e7> in <module>
#       1 a1="shreya"
# ----> 2 int(a1)
#
# TypeError: 'int' object is not callable

# %%
int(1.54)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-b6d6cee5b120> in <module>
# ----> 1 int(1.54)
#
# TypeError: 'int' object is not callable

# %%
int(1.9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-497a7b484349> in <module>
# ----> 1 int(1.9)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### concatination

# %%
1+1
# Out:
# 2

# %%
int("1")+int("1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-d18757851756> in <module>
# ----> 1 int("1")+int("1")
#
# TypeError: 'int' object is not callable

# %%
int("1")+("1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-560b6a6a5430> in <module>
# ----> 1 int("1")+("1")
#
# TypeError: 'int' object is not callable

# %%
"1"*"1"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-85cf2e5a5750> in <module>
# ----> 1 "1"*"1"
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
"1"*10
# Out:
# '1111111111'

# %%
a="int"
int(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-9c74fe7065ad> in <module>
#       1 a="int"
# ----> 2 int(a)
#
# TypeError: 'int' object is not callable

# %%
bool(2)
# Out:
# True

# %%
bool(-19)
# Out:
# True

# %%
a=10
a
# Out:
# 10

# %%
a=12

# %%
a
# Out:
# 12

# %%
a=12
a
# Out:
# 12

# %%
print("HEllo this is Kalyan Krishna")
# Out:
# HEllo this is Kalyan Krishna
